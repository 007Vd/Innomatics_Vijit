# %% [markdown]
# Q1

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Q2

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if n%2!=0:
        print("Weird")
    elif n>=2 and n<=5:
        print("Not Weird")
    elif n>=6 and n<=20:
        print("Weird")
    else:
        print("Not Weird")

# %% [markdown]
# Q3

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)

# %% [markdown]
# Q4

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    first_lineans=a//b
    second_lineans=a/b
    print(first_lineans)
    print(second_lineans)

# %% [markdown]
# Q5

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(0,n,1):
        print(i*i)

# %% [markdown]
# Q6

# %%
def is_leap(year):
    leap = False
    
    if(year%400==0 or (year%4==0 and year%100!= 0 )):
        leap= True
    
    return leap

year = int(input())
print(is_leap(year))

# %% [markdown]
# Q7

# %%
if __name__ == '__main__':
    n = int(input())
    ans=""
    for i in range(1,n+1,1):
        ans=ans+str(i)    
    print(ans)
